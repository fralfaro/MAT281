# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/labs/lab_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°15: Modelos de Clasificacion Supervisada
#
# ## Objetivos del laboratorio
#
# * Plantear un problema de clasificacion binaria.
# * Interpretar la matriz de confusion y metricas (accuracy, precision, recall, F1).
# * Entrenar regresion logistica y arboles de decision.
# * Construir e interpretar la curva ROC y el AUC.
# * Analizar el desbalance de clases y el efecto del umbral de decision.
#
# ## Instrucciones
#
# Lea con atencion cada problema antes de resolverlo. Reemplace cada celda que contiene `# FIXME` con su propia solucion y, cuando se solicite, **responda las preguntas** en celdas de texto.
#
# > **Nota:** Puede apoyarse en asistentes virtuales (ChatGPT, Gemini, Claude) o en el autocompletado de Colab, pero asegurese de **entender** cada linea de codigo que entregue.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Problema 01 — El problema de clasificacion
#
# Usaremos el dataset **Breast Cancer** de scikit-learn (clasificar tumores como
# benignos o malignos).
#
# **Tu tarea:**
#
# 1. Carga `load_breast_cancer(as_frame=True)`.
# 2. Separa `X` e `y`, divide en train/test (estratificado) y **estandariza** `X`.
# 3. ¿Cuantos casos de cada clase hay? ¿Esta balanceado?

# %%
from sklearn.datasets import load_breast_cancer

# FIXME

# %% [markdown]
# ## Problema 02 — Regresion logistica y metricas
#
# **Tu tarea:**
#
# 1. Entrena una `LogisticRegression`.
# 2. Calcula **accuracy, precision, recall y F1** (`classification_report`).
# 3. Muestra la **matriz de confusion** (`ConfusionMatrixDisplay`).
# 4. **Pregunta:** en el contexto de un diagnostico de cancer, ¿que error es mas
#    grave: un falso positivo o un falso negativo? ¿Que metrica priorizarias?

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, ConfusionMatrixDisplay

# FIXME

# %% [markdown]
# **Respuesta (Problema 02):** *(escribe aqui)*

# %% [markdown]
# ## Problema 03 — Arbol de decision
#
# **Tu tarea:**
#
# 1. Entrena un `DecisionTreeClassifier` (limita `max_depth` para evitar
#    sobreajuste).
# 2. Compara sus metricas con las de la regresion logistica.
# 3. (Opcional) Visualiza el arbol con `plot_tree`.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# FIXME

# %% [markdown]
# ## Problema 04 — Curva ROC y AUC
#
# **Tu tarea:**
#
# 1. Obten las probabilidades predichas (`predict_proba`) de la clase positiva.
# 2. Grafica la **curva ROC** (`RocCurveDisplay`) y reporta el **AUC**.
# 3. **Pregunta:** ¿que representa el AUC? ¿Que valor tendria un clasificador
#    aleatorio?

# %%
from sklearn.metrics import RocCurveDisplay, roc_auc_score

# FIXME

# %% [markdown]
# **Respuesta (Problema 04):** *(escribe aqui)*

# %% [markdown]
# ## Problema 05 — Umbral de decision
#
# Por defecto se clasifica como positivo si $P > 0.5$, pero el umbral se puede
# ajustar.
#
# **Tu tarea:**
#
# 1. Prueba umbrales de 0.3, 0.5 y 0.7 sobre las probabilidades.
# 2. Para cada umbral reporta precision y recall.
# 3. **Pregunta:** ¿como cambia el equilibrio precision/recall al mover el umbral?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 05):** *(escribe aqui)*
