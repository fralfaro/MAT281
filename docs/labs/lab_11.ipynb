# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/labs/lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°11: Inferencia en Regresion Lineal Simple
#
# ## Objetivos del laboratorio
#
# * Ajustar un modelo de regresion lineal simple con `statsmodels`.
# * Leer e interpretar la tabla `summary()` (coeficientes, $R^2$, errores).
# * Realizar pruebas t sobre los coeficientes e interpretar sus valores-p.
# * Construir intervalos de confianza para los coeficientes y predicciones.
# * Diagnosticar el modelo analizando los residuos.
#
# ## Instrucciones
#
# Lea con atencion cada problema antes de resolverlo. Reemplace cada celda que contiene `# FIXME` con su propia solucion y, cuando se solicite, **responda las preguntas** en celdas de texto.
#
# > **Nota:** Puede apoyarse en asistentes virtuales (ChatGPT, Gemini, Claude) o en el autocompletado de Colab, pero asegurese de **entender** cada linea de codigo que entregue.
#
# > **Requisito:** `# !pip install statsmodels`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf

df = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281/main/docs/lectures/statistics/data/supermarket_sales.csv")
df.head()

# %% [markdown]
# ## Problema 01 — Visualizacion de la relacion
#
# Modelaremos el `Total` de la venta en funcion del `Unit price`.
#
# **Tu tarea:**
#
# 1. Construye un grafico de dispersion de `Total` (eje Y) vs `Unit price` (eje X).
# 2. Añade una recta de tendencia con `sns.regplot`.
# 3. **Pregunta:** ¿la relacion se ve positiva, negativa o nula?

# %%
# FIXME

# %% [markdown]
# ## Problema 02 — Ajuste del modelo
#
# **Tu tarea:**
#
# 1. Ajusta el modelo $\text{Total} = \beta_0 + \beta_1\,\text{UnitPrice} + \epsilon$
#    con `smf.ols(...).fit()`.
# 2. Muestra el `summary()`.
# 3. Escribe la **ecuacion estimada** de la recta con los coeficientes obtenidos.

# %%
# FIXME

# %% [markdown]
# **Ecuacion estimada (Problema 02):** *(escribe aqui)*

# %% [markdown]
# ## Problema 03 — Pruebas t sobre los coeficientes
#
# **Tu tarea:** a partir del `summary()`:
#
# 1. Identifica el **valor-p** del coeficiente de `Unit price`.
# 2. Con $\alpha = 0.05$: ¿es `Unit price` un predictor estadisticamente
#    significativo del `Total`?
# 3. Interpreta el valor del coeficiente $\beta_1$ en el contexto del problema.

# %% [markdown]
# **Respuesta (Problema 03):** *(escribe aqui)*

# %% [markdown]
# ## Problema 04 — Intervalos de confianza
#
# **Tu tarea:**
#
# 1. Obten los IC del 95% para los coeficientes con `modelo.conf_int()`.
# 2. Interpreta el intervalo del coeficiente $\beta_1$.
# 3. **Pregunta:** ¿el intervalo de $\beta_1$ contiene al 0? ¿Es coherente con la
#    prueba t del problema anterior?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 04):** *(escribe aqui)*

# %% [markdown]
# ## Problema 05 — Diagnostico de residuos
#
# **Tu tarea:**
#
# 1. Calcula los **residuos** (`modelo.resid`) y los valores ajustados
#    (`modelo.fittedvalues`).
# 2. Grafica residuos vs valores ajustados. ¿Se observa algun patron (que indicaria
#    problemas) o se ven aleatorios?
# 3. Grafica un **QQ-plot** de los residuos (`sm.qqplot`). ¿Parecen normales?

# %%
# FIXME

# %% [markdown]
# **Conclusion del diagnostico (Problema 05):** *(escribe aqui)*
