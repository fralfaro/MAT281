# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/labs/lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°04: Manipulacion de Datos con Pandas II
#
# ## Objetivos del laboratorio
#
# * Agregar y resumir informacion con `groupby` y funciones de agregacion.
# * Aplicar agregaciones multiples y funciones personalizadas.
# * Combinar tablas con `concat` y `merge` (distintos tipos de join).
# * Reorganizar datos entre formatos **wide** y **long** (`pivot` / `melt`).
# * Construir un flujo de analisis exploratorio sobre datos reales.
#
# ## Instrucciones
#
# Lea con atencion cada problema antes de resolverlo. Reemplace cada celda que contiene `# FIXME` con su propia solucion y, cuando se solicite, **responda las preguntas** en celdas de texto.
#
# > **Nota:** Puede apoyarse en asistentes virtuales (ChatGPT, Gemini, Claude) o en el autocompletado de Colab, pero asegurese de **entender** cada linea de codigo que entregue.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Dataset: Indice de Libertad de Prensa
#
# Trabajaremos con tres archivos:
#
# * `libertad_prensa_01.csv` y `libertad_prensa_02.csv`: indicadores por pais en
#   distintos periodos.
# * `libertad_prensa_codigo.csv`: tabla de codigos/paises para combinar.

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281/main/docs/labs/data/libertad_prensa_01.csv")
df2 = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281/main/docs/labs/data/libertad_prensa_02.csv")
cod = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281/main/docs/labs/data/libertad_prensa_codigo.csv")

display(df1.head())
display(df2.head())
display(cod.head())

# %% [markdown]
# ## Problema 01 — Concatenacion
#
# **Tu tarea:**
#
# 1. Inspecciona las columnas de `df1` y `df2`. Si comparten estructura,
#    **concatenalos verticalmente** (`pd.concat`) en un unico DataFrame `df`.
# 2. Reporta cuantas filas tiene el resultado y verifica que no se hayan perdido
#    datos.

# %%
# FIXME

# %% [markdown]
# ## Problema 02 — Groupby basico
#
# Usando el DataFrame combinado:
#
# **Tu tarea:**
#
# 1. Calcula el **puntaje promedio** del indice por año.
# 2. Calcula, por **region/continente** (la columna que corresponda), el promedio,
#    minimo y maximo del indice.
# 3. ¿Cual es el grupo con el peor indice promedio?

# %%
# FIXME

# %% [markdown]
# ## Problema 03 — Agregaciones multiples y funciones personalizadas
#
# **Tu tarea:**
#
# 1. Usando `.agg()`, calcula simultaneamente `mean`, `std` y `count` del indice
#    por grupo.
# 2. Define una funcion personalizada `rango(x)` que retorne `x.max() - x.min()` y
#    aplicala con `groupby(...).agg(rango)`.

# %%
def rango(x):
    # FIXME
    pass


# FIXME

# %% [markdown]
# ## Problema 04 — Merge (combinar tablas)
#
# **Tu tarea:**
#
# 1. Combina (`pd.merge`) el DataFrame de indices con la tabla de codigos `cod`
#    usando la columna comun (codigo o nombre de pais).
# 2. Usa un `how="left"` y verifica cuantos paises **no** encontraron coincidencia.
# 3. Explica brevemente la diferencia entre un `inner`, `left` y `outer` join.

# %%
# FIXME

# %% [markdown]
# **Respuesta (joins):** *(explica aqui)*

# %% [markdown]
# ## Problema 05 — Formatos wide y long
#
# **Tu tarea:**
#
# 1. Construye una tabla **wide** con `pivot_table`: filas = pais, columnas = año,
#    valores = indice.
# 2. Vuelve al formato **long** con `melt`.
# 3. **Pregunta:** ¿en que situaciones es preferible el formato *long* (por ejemplo,
#    para graficar con seaborn)?

# %%
# FIXME

# %% [markdown]
# **Respuesta:** *(escribe aqui)*
