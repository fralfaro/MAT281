# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/labs/lab_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°03: Manipulacion de Datos con Pandas I
#
# ## Objetivos del laboratorio
#
# * Cargar datos desde un archivo CSV a un `DataFrame`.
# * Realizar exploracion basica: dimensiones, tipos, estadisticos y nulos.
# * Seleccionar, crear y transformar columnas (incluyendo `apply`).
# * Filtrar filas con condiciones numericas, de texto y combinadas.
# * Detectar y tratar valores nulos y duplicados; manipular fechas.
#
# ## Instrucciones
#
# Lea con atencion cada problema antes de resolverlo. Reemplace cada celda que contiene `# FIXME` con su propia solucion y, cuando se solicite, **responda las preguntas** en celdas de texto.
#
# > **Nota:** Puede apoyarse en asistentes virtuales (ChatGPT, Gemini, Claude) o en el autocompletado de Colab, pero asegurese de **entender** cada linea de codigo que entregue.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Dataset: Netflix Titles
#
# Trabajaremos con `netflix_titles.csv`, que contiene los titulos disponibles en
# Netflix hasta 2021 (peliculas y series, con director, reparto, pais, año, etc.).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281/main/docs/labs/data/netflix_titles.csv")
df.head()

# %% [markdown]
# ## Problema 01 — Exploracion inicial
#
# **Tu tarea:** responde con codigo:
#
# 1. ¿Cuantas filas y columnas tiene el dataset?
# 2. ¿Que tipo de dato tiene cada columna? (`dtypes`)
# 3. Muestra los estadisticos descriptivos de las columnas numericas.
# 4. ¿Cuantos valores nulos hay por columna? Ordenalos de mayor a menor.

# %%
# FIXME

# %% [markdown]
# ## Problema 02 — Exploracion por columna
#
# **Tu tarea:**
#
# 1. ¿Cuantas peliculas (`Movie`) y cuantas series (`TV Show`) hay? (columna `type`).
# 2. Lista los 10 paises (`country`) con mas titulos.
# 3. ¿En que `release_year` se estrenaron mas titulos?

# %%
# FIXME

# %% [markdown]
# ## Problema 03 — Crear y transformar columnas
#
# **Tu tarea:**
#
# 1. La columna `duration` mezcla `"90 min"` (peliculas) y `"3 Seasons"` (series).
#    Crea una columna numerica `duracion_num` extrayendo solo el numero
#    (usa `str.extract` o `apply`).
# 2. Crea una columna `decada` a partir de `release_year`
#    (por ejemplo, 1995 -> 1990).
# 3. Usando `apply`, crea `titulo_largo` que sea `True` si el `title` tiene mas de
#    20 caracteres.

# %%
# FIXME

# %% [markdown]
# ## Problema 04 — Filtrado de datos
#
# **Tu tarea:** obten subconjuntos del DataFrame que cumplan:
#
# 1. Peliculas (`type == "Movie"`) estrenadas **despues de 2015**.
# 2. Titulos cuyo `country` sea exactamente `"Mexico"` **o** `"Argentina"`
#    (usa `isin`).
# 3. Titulos cuyo `title` contenga la palabra `"Love"`
#    (filtro de texto, sin distinguir mayusculas).

# %%
# FIXME

# %% [markdown]
# ## Problema 05 — Nulos, duplicados y fechas
#
# **Tu tarea:**
#
# 1. La columna `director` tiene muchos nulos: rellenalos con `"Desconocido"`.
# 2. Verifica si existen filas duplicadas (`duplicated`) y eliminalas si las hay.
# 3. Convierte `date_added` a tipo fecha (`pd.to_datetime`) y crea una columna
#    `anio_agregado` con el año en que se agrego el titulo a la plataforma.
# 4. **Pregunta:** ¿en que año se agregaron mas titulos a Netflix?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 05):** *(escribe aqui)*
