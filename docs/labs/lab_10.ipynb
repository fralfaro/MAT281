# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/labs/lab_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°10: Intervalos de Confianza
#
# ## Objetivos del laboratorio
#
# * Interpretar correctamente el significado de un intervalo de confianza (IC).
# * Construir IC para la media (con $\sigma$ conocida y desconocida).
# * Construir IC para diferencia de medias y para proporciones.
# * Verificar la **cobertura** de un IC mediante simulacion.
# * Conectar el IC con la prueba de hipotesis.
#
# ## Instrucciones
#
# Lea con atencion cada problema antes de resolverlo. Reemplace cada celda que contiene `# FIXME` con su propia solucion y, cuando se solicite, **responda las preguntas** en celdas de texto.
#
# > **Nota:** Puede apoyarse en asistentes virtuales (ChatGPT, Gemini, Claude) o en el autocompletado de Colab, pero asegurese de **entender** cada linea de codigo que entregue.

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/fralfaro/MAT281/main/docs/lectures/statistics/data/supermarket_sales.csv")
rng = np.random.default_rng(7)
df.head()

# %% [markdown]
# ## Problema 01 — IC para la media ($\sigma$ desconocida)
#
# **Tu tarea:**
#
# 1. Toma una muestra de $n=40$ valores de `Total`.
# 2. Construye un **IC del 95%** para la media usando la distribucion t:
#
#    $$ \bar{x} \pm t_{1-\alpha/2,\,n-1}\,\frac{s}{\sqrt{n}} $$
#
#    (puedes usar `stats.t.interval`).
# 3. Interpreta el intervalo **en palabras**.

# %%
# FIXME

# %% [markdown]
# **Interpretacion (Problema 01):** *(escribe aqui)*

# %% [markdown]
# ## Problema 02 — Efecto del nivel de confianza
#
# **Tu tarea:**
#
# 1. Para la misma muestra, construye IC al **90%, 95% y 99%**.
# 2. **Pregunta:** ¿que ocurre con el **ancho** del intervalo a medida que aumenta
#    el nivel de confianza? ¿Por que?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 02):** *(escribe aqui)*

# %% [markdown]
# ## Problema 03 — IC para diferencia de medias
#
# **Tu tarea:**
#
# 1. Separa `Total` por `Gender` (Male / Female).
# 2. Construye un IC del 95% para la **diferencia de medias**.
# 3. **Pregunta:** ¿el intervalo contiene al 0? ¿que implica eso respecto a si las
#    medias difieren?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 03):** *(escribe aqui)*

# %% [markdown]
# ## Problema 04 — IC para una proporcion
#
# **Tu tarea:**
#
# 1. Calcula la proporcion de clientes que pagan con `Ewallet` (columna `Payment`).
# 2. Construye un IC del 95% para esa proporcion usando la aproximacion Normal:
#
#    $$ \hat{p} \pm z_{1-\alpha/2}\,\sqrt{\frac{\hat{p}(1-\hat{p})}{n}} $$

# %%
# FIXME

# %% [markdown]
# ## Problema 05 — Simulacion de cobertura
#
# Un IC del 95% deberia "atrapar" al verdadero parametro en ~95% de los casos.
#
# **Tu tarea:**
#
# 1. Considera `Total` como poblacion y su media $\mu$ como verdadero valor.
# 2. Repite **1000 veces**: toma una muestra de $n=40$, construye su IC del 95% y
#    verifica si contiene a $\mu$.
# 3. Reporta el **porcentaje de cobertura**. ¿Se acerca al 95%?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 05):** *(escribe aqui)*
