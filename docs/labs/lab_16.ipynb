# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/labs/lab_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # MAT281 - Laboratorio N°16: Aprendizaje No Supervisado: Clustering y PCA
#
# ## Objetivos del laboratorio
#
# * Comprender la diferencia entre aprendizaje supervisado y no supervisado.
# * Aplicar el algoritmo **K-Means** y elegir `k` (codo y silueta).
# * Perfilar e interpretar los clusters obtenidos.
# * Reducir dimensionalidad con **PCA** y analizar la varianza explicada.
# * Combinar PCA + K-Means para visualizar agrupamientos.
#
# ## Instrucciones
#
# Lea con atencion cada problema antes de resolverlo. Reemplace cada celda que contiene `# FIXME` con su propia solucion y, cuando se solicite, **responda las preguntas** en celdas de texto.
#
# > **Nota:** Puede apoyarse en asistentes virtuales (ChatGPT, Gemini, Claude) o en el autocompletado de Colab, pero asegurese de **entender** cada linea de codigo que entregue.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# ## Problema 01 — Preparacion de datos
#
# Usaremos el dataset **Wine** de scikit-learn (13 variables quimicas de vinos).
# En clustering **ignoramos la etiqueta** y buscamos estructura en los datos.
#
# **Tu tarea:**
#
# 1. Carga `load_wine(as_frame=True)` y separa solo la matriz `X`.
# 2. **Estandariza** todas las variables (clave para K-Means y PCA).
# 3. **Pregunta:** ¿por que la estandarizacion es importante antes de K-Means?

# %%
from sklearn.datasets import load_wine

# FIXME

# %% [markdown]
# **Respuesta (Problema 01):** *(escribe aqui)*

# %% [markdown]
# ## Problema 02 — K-Means y eleccion de k
#
# **Tu tarea:**
#
# 1. Aplica el **metodo del codo**: ajusta K-Means para $k = 1..10$ y grafica la
#    inercia (`inertia_`).
# 2. Calcula el **coeficiente de silueta** (`silhouette_score`) para $k = 2..6$.
# 3. **Pregunta:** ¿que valor de `k` sugieren ambos criterios?

# %%
from sklearn.metrics import silhouette_score

# FIXME

# %% [markdown]
# **Respuesta (Problema 02):** *(escribe aqui)*

# %% [markdown]
# ## Problema 03 — Perfilado de clusters
#
# **Tu tarea:**
#
# 1. Ajusta K-Means con el `k` elegido y asigna la etiqueta de cluster a cada vino.
# 2. Calcula la **media de cada variable por cluster** (`groupby`).
# 3. **Pregunta:** describe en palabras que caracteriza a cada grupo.

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 03):** *(escribe aqui)*

# %% [markdown]
# ## Problema 04 — PCA y varianza explicada
#
# **Tu tarea:**
#
# 1. Aplica `PCA` sobre los datos estandarizados.
# 2. Grafica la **varianza explicada acumulada** en funcion del numero de
#    componentes.
# 3. **Pregunta:** ¿cuantas componentes se necesitan para explicar al menos el 80%
#    de la varianza?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 04):** *(escribe aqui)*

# %% [markdown]
# ## Problema 05 — PCA + K-Means en 2D
#
# **Tu tarea:**
#
# 1. Proyecta los datos a las **2 primeras componentes** principales.
# 2. Grafica un scatter coloreado por la etiqueta de cluster de K-Means.
# 3. **Pregunta:** ¿se distinguen visualmente los grupos en el plano de las dos
#    primeras componentes?

# %%
# FIXME

# %% [markdown]
# **Respuesta (Problema 05):** *(escribe aqui)*
